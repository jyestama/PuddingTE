# %% [markdown]
# # Two band model with pudding mold dispersion
#
# We will investigate the thermoelectric properties of a material with a pudding mold dispersion, with bandgap $E_g = 2\Delta$:
#
# \begin{equation}
# E = \pm(Ak^n+\Delta), \quad ~n~even
# \end{equation}
#
# using the two-band model and the constant relaxation time approximation.
#
# $A$ is normalized according to $Ak^n=1$ when $k$ is at the band edge $k=\sqrt{d}\pi$ (Taking the lattice contant $a=1$); that is,
#
# \begin{equation}
# A = \left(\frac{1}{\sqrt{d}\pi}\right)^n
# \end{equation}
#
# The group velocity of this (2D) material is given by (taking the conduction band for convenience)
#
# \begin{equation}
# v = \hbar^{-1} \frac{dE}{dk} = nAk^{n-1} = nA\hbar^{-1} \left(\frac{E-\Delta}{A}\right)^{(n-1)/n}
# \end{equation}
#
# while the density of states $\mathcal{D}(E)$ for a two dimensional system will be given by
#
# \begin{equation}
# \mathcal{D}(E)=\frac{1}{(2\pi)^2}\int d^2\textbf{k}~\delta(E_\textbf{k}-E) = \frac{1}{(2\pi)}\int k dk~\delta(E_\textbf{k}-E)
# \end{equation}
#
# with $dk = dE (nA)^{-1}k^{1-n}$, $k dk = dE (nA)^{-1}k^{2-n}$. Plugging in the value of $k dk$ , we have
#
# \begin{equation}
# \mathcal{D}(E) = \frac{1}{(2\pi nA)}\int \left(\frac{E_k-\Delta}{A}\right)^{(2-n)/n} ~\delta(E_\textbf{k}-E) dE_k
# \end{equation}
#
# \begin{equation}
# \mathcal{D}(E) = \frac{1}{2\pi nA} \left(\frac{E-\Delta}{A}\right)^{(2-n)/n}
# \end{equation}
#
# Therefore, the thermoelectric integral for the condunction band can be written as
#
# \begin{equation}
# \mathcal{L}_{c,i} = \int_{\Delta}^{\infty} \tau \frac{1}{2\pi nA} \frac{1}{2\hbar^2}\left(\frac{E-\Delta}{A}\right)^{(2-n)/n} \left(nA \left(\frac{E-\Delta}{A}\right)^{(n-1)/n}\right)^2 \left(-\frac{\partial f}{\partial E}\right) (E-\mu)^i dE
# \end{equation}
#
# \begin{equation}
# \mathcal{L}_{c,i} = \frac{\tau n}{4\pi\hbar^2} \int_{\Delta}^{\infty} (E-\Delta) (k_B T)^{-1} \frac{\exp(\frac{E-\mu}{k_BT})}{(\exp(\frac{E-\mu}{k_BT})+1)^2}(E-\mu)^i dE
# \end{equation}
#
# We note that this quantity is independent of the exponent $n$ aside from an extra factor $n$.
#
# To solve this integral, let $(E-\mu)/k_B T = x$, $\mu/k_B T = \eta$, and $\Delta/k_B T = \Delta'$. Then,
#
# \begin{align}
# \mathcal{L}_{c,i} &= \frac{\tau n}{4\pi \hbar^2}\int_{\Delta'-\eta}^{\infty} (x+\eta - \Delta')(k_B T)^i x^i \frac{e^x}{(e^x+1)^2} (k_B T) dx \\
# \mathcal{L}_{c,i} &= \frac{\tau n(k_B T)^{i+1}}{4\pi \hbar^2}\left(\int_{\Delta'-\eta}^{\infty} x^{i+1} \frac{e^x}{(e^x+1)^2} dx + (\eta-\Delta')\int_{\Delta'-\eta}^{\infty} x^i \frac{e^x}{(e^x+1)^2} dx \right)\\
# \mathcal{L}_{c,i} &= \frac{\tau n(k_B T)^{i+1}}{4\pi \hbar^2}(\mathcal{F}_{i+1} (\eta-\Delta') + (\eta-\Delta')\mathcal{F}_{i}(\eta-\Delta'))
# \end{align}
#
# where
#
# \begin{equation}
# \mathcal{F}_{i}(a) = \int_{-a}^{\infty} x^i \frac{e^x}{(e^x+1)^2} dx
# \end{equation}
#
# Similarly, for the valence band,
#
# \begin{equation}
# E = -Ak^n-\Delta
# \end{equation}
#
# \begin{equation}
# v = -nA \hbar{-1} k^{n-1} = -nA\hbar^{-1} \left(\frac{-E-\Delta}{A}\right)^{(n-1)/n}
# \end{equation}
#
# and
#
# \begin{equation}
# \mathcal{D}(E) = \frac{1}{(2\pi)}\int k dk~\delta(E_\textbf{k}-E)
# \end{equation}
#
# with $k dk = -k/(nAk^{n-1}) dE = -\frac{1}{nA}(-E-\Delta)^{(2-n)/n} dE$
#
# \begin{equation}
# \mathcal{D}(E) = \frac{1}{2\pi nA} \left(\frac{-E-\Delta}{A}\right)^{(2-n)/n}
# \end{equation}
#
# and
#
# \begin{equation}
# \mathcal{L}_{v,i} = \frac{\tau n}{4\pi\hbar^2} \int_{-\infty}^{-\Delta} (-E-\Delta) (k_B T)^{-1} \frac{\exp(\frac{E-\mu}{k_BT})}{(\exp(\frac{E-\mu}{k_BT})+1)^2}(E-\mu)^i dE
# \end{equation}
#
# Using a similar substitution $x = (E-\mu)/k_B T$,
#
# \begin{equation}
# \mathcal{L}_{v,i} = -\frac{\tau n}{4\pi\hbar^2} \int_{-\infty}^{-\Delta'-\eta} (x+\eta+\Delta') \frac{e^x}{(e^x+1)^2} (x)^i (k_B T)^i d(k_B T x)
# \end{equation}
#
# \begin{equation}
# \mathcal{L}_{v,i} = -\frac{\tau n (k_B T)^{i+1}}{4\pi\hbar^2} \left(\int_{-\infty}^{-\Delta'-\eta} x^{i+1} \frac{e^x}{(e^x+1)^2} dx + (\eta+\Delta') \int_{-\infty}^{-\Delta'-\eta} x^i \frac{e^x}{(e^x+1)^2} dx \right)
# \end{equation}
#
# 3D and 1D
#
# For a 3D system,
#
# \begin{equation}
# \mathcal{L}_{c,i} = \int_{\Delta}^{\infty} \tau \frac{1}{2\pi^2 nA} \frac{1}{3\hbar}\left(\frac{E-\Delta}{A}\right)^{(3-n)/n} \left(nA \left(\frac{E-\Delta}{A}\right)^{(n-1)/n}\right)^2 \left(-\frac{\partial f}{\partial E}\right) (E-\mu)^i dE
# \end{equation}
#
# \begin{equation}
# \mathcal{L}_{c,i} = \frac{\tau n A}{6\pi^2 \hbar} \int_{\Delta}^{\infty} \left(\frac{E-\Delta}{A}\right)^{(1+n)/n} \frac{\exp(\frac{E-\mu}{k_BT})}{(\exp(\frac{E-\mu}{k_BT})+1)^2}(E-\mu)^i dE
# \end{equation}
#
# By substituting $(E-\mu)/k_B T = x$ we have
#
# \begin{equation}
# \mathcal{L}_{c,i}=\frac{\tau n (k_B T)^{i+1+1/n}}{6\pi^2 \hbar^2 A^{1/n}} \int_{\Delta'-\eta}^{\infty} (x+\eta-\Delta')^{(1+n)/n}(x)^i \frac{\exp(x)}{(\exp(x)+1)^2} dx
# \end{equation}
#
# For the valence band,
#
# \begin{equation}
# \mathcal{L}_{c,i}=\frac{\tau n (k_B T)^{i+1+1/n}}{6\pi^2 \hbar^2 A^{1/n}} \int_{-\infty}^{-\Delta'-\eta} (-x-\eta-\Delta')^{(1+n)/n}(x)^i \frac{\exp(x)}{(\exp(x)+1)^2} dx
# \end{equation}

# %%
# Call necessary mathematical and numerical libraries
from numpy import frompyfunc, linspace, exp, log, pi, zeros
from mpmath import polylog
from scipy.integrate import quad

# Call plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)        # controls default text sizes
plt.rc('legend', fontsize=SMALL_SIZE)  # legend fontsize
plt.rc('xtick', labelsize=MEDIUM_SIZE) # fontsize of the x tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE) # fontsize of the y tick labels
plt.rc('axes', labelsize=BIGGER_SIZE)  # fontsize of the x and y labels

# %%
#Define functions for 3D system

infty = 100
kT_A  = 0.013   #Boltzmann constant times temperature
a = 5.44        #Normalization factor A
C2 = 1/(4*pi)
C3 = 1/(6*pi*pi)
kph = a*(kT_A)


# Define kernel:
def L0c(xx,N,D):
    def integrand (x,xx):
        return (x+xx-D)**((1+N)/N) * (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, D-xx, infty, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L1c(xx,N,D):
    def integrand (x,xx):
        return (x+xx-D)**((1+N)/N)*x* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, D-xx, infty, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L2c(xx,N,D):
    def integrand (x,xx):
        return (x+xx-D)**((1+N)/N) * (x**2)* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, D-xx, infty, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L0v(xx,N,D):
    def integrand (x,xx):
        return (-x-xx-D)**((1+N)/N) * (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, -infty, -D-xx, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L1v(xx,N,D):
    def integrand (x,xx):
        return (-x-xx-D)**((1+N)/N)*x* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, -infty, -D-xx, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L2v(xx,N,D):
    def integrand (x,xx):
        return (-x-xx-D)**((1+N)/N) * (x**2)* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, -infty, -D-xx, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def S_c(x,n,W):
    sc = zeros(x.size)
    for i in range(x.size):
        sc[i] = -L1c(x[i],n,W)/L0c(x[i],n,W)
    return sc

def sigma_c(x,n,W):
    sgm = zeros(x.size)
    for i in range(x.size):
        sgm[i] = L0c(x[i],n,W)
    return sgm

def kappa_c(x,n,W):
    kpp = zeros(x.size)
    for i in range(x.size):
        kpp[i] = (L2c(x[i],n,W)-(L1c(x[i],n,W)**2/L0c(x[i],n,W)))
    return kpp

def S_v(x,n,W):
    sc = zeros(x.size)
    for i in range(x.size):
        sc[i] = -L1v(x[i],n,W)/L0v(x[i],n,W)
    return sc

def sigma_v(x,n,W):
    sgm = zeros(x.size)
    for i in range(x.size):
        sgm[i] = L0v(x[i],n,W)
    return sgm

def kappa_v(x,n,W):
    kpp = zeros(x.size)
    for i in range(x.size):
        kpp[i] = (L2v(x[i],n,W)-(L1v(x[i],n,W)**2/L0v(x[i],n,W)))
    return kpp

def sigma(x,m,n,W):
    return sigma_c(x,m,W)+sigma_v(x,n,W)

def S(x,m,n,W):
    return (sigma_c(x,m,W)*S_c(x,m,W)+sigma_v(x,n,W)*S_v(x,n,W))/sigma(x,m,n,W)

def kappa(x,m,n,W):
    return kappa_c(x,m,W)+kappa_v(x,n,W)+(sigma_c(x,m,W)*sigma_v(x,n,W)*(S_c(x,m,W)-S_v(x,n,W))**2)/sigma(x,m,n,W)


def PF(Sc,Sgm):
    return (Sc**2)*Sgm

def ZT(x,m,n,W,alpha):
    return (S(x,m,n,W)**2 * sigma(x,m,n,W))/(kappa(x,m,n,W) + alpha)

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 

ZT3D22Delta3 = ZT(eta,2,2,3,0)
ZT3D44Delta3 = ZT(eta,4,4,3,0)
ZT3D66Delta3 = ZT(eta,6,6,3,0)
ZT3D22Delta5 = ZT(eta,2,2,5,0)
ZT3D44Delta5 = ZT(eta,4,4,5,0)
ZT3D66Delta5 = ZT(eta,6,6,5,0)

# %%
#Plotting S sigma kappa for varying n

#For S, sigma, kappa, the input for the function is (chemical potential, conduction band shape, valence band shape, band gap)
#For ZT the input for the function is (chemical potential, conduction band shape, valence band shape, band gap, phonon conductivity)


npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,2,3), 'b-', label="$n=2$")
plt.plot(eta, sigma(eta,4,4,3), 'r-', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma(\sigma_0)$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,2,3), 'b-', label="$n=2$")
plt.plot(eta, kappa(eta,4,4,3), 'r-', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e(\kappa_0)$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,2,3), 'b-', label="$n=2$")
plt.plot(eta, S(eta,4,4,3), 'r-', label="$n=4$")
plt.plot(eta, S(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S(S_0)$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,2,3)**2*sigma(eta,2,2,3), 'b-')
plt.plot(eta,S(eta,4,4,3)**2*sigma(eta,4,4,3), 'r-')
plt.plot(eta,S(eta,6,6,3)**2*sigma(eta,6,6,3), 'g-')
plt.axis([-8,8,0,2])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF (S_0^2 \sigma_0)$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,2,3,0), 'b-', label="$n=2$")
ax5.plot(eta, ZT(eta,4,4,3,0), 'r-', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,3,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b-',label="$n=2$")
ax6.plot(eta,fil+20,'r-',label="$n=4$")
ax6.plot(eta,fil+20,'g-',label="$n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_n_3D.pdf')

# %%
#Plotting S sigma kappa for varying n

npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(10,3))

ax1 = plt.subplot(1,3,1)
plt.plot(eta, sigma_c(eta,2,3), 'b--', label="$\sigma_c$")
plt.plot(eta, sigma_v(eta,2,3), 'r--', label="$\sigma_v$")
plt.plot(eta, sigma(eta,2,2,3), 'g-', label="$\sigma$")
plt.axis([-8,8,0,0.5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma (\sigma_0)$')
#plt.title('(a)')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(1,3,2)
plt.plot(eta, kappa_c(eta,2,3), 'b--', label="$\kappa_{e,c}$")
plt.plot(eta, kappa_v(eta,2,3), 'r--', label="$\kappa_{e,v}$")
plt.plot(eta, kappa(eta,2,2,3), 'g-', label="$\kappa_e$")
plt.axis([-8,8,0,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('n=2',fontsize=14)
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e (\kappa_0)$')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(1,3,3)
plt.plot(eta, S_c(eta,2,3), 'b--', label="$S_c$")
plt.plot(eta, S_v(eta,2,3), 'r--', label="$S_v$")
plt.plot(eta, S(eta,2,2,3), 'g-', label="$S$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S (S_0)$')
plt.legend(loc='upper right')
plt.tight_layout()

plt.savefig('figTESsigkap_2_3D.pdf')

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(10,3))

ax1 = plt.subplot(1,3,1)
plt.plot(eta, sigma_c(eta,4,3), 'b--', label="$\sigma_c$")
plt.plot(eta, sigma_v(eta,4,3), 'r--', label="$\sigma_v$")
plt.plot(eta, sigma(eta,4,4,3), 'g-', label="$\sigma$")
plt.axis([-8,8,0,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma(\sigma_0)$')
#plt.title('(a)')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(1,3,2)
plt.plot(eta, kappa_c(eta,4,3), 'b--', label="$\kappa_{e,c}$")
plt.plot(eta, kappa_v(eta,4,3), 'r--', label="$\kappa_{e,v}$")
plt.plot(eta, kappa(eta,4,4,3), 'g-', label="$\kappa_e$")
plt.axis([-8,8,0,3]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('n=4',fontsize=14)
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e(\kappa_0)$')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(1,3,3)
plt.plot(eta, S_c(eta,4,3), 'b--', label="$S_c$")
plt.plot(eta, S_v(eta,4,3), 'r--', label="$S_v$")
plt.plot(eta, S(eta,4,4,3), 'g-', label="$S$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S(S_0)$')
plt.legend(loc='upper right')
plt.tight_layout()

plt.savefig('figTESsigkap_4_3D.pdf')

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(10,3))

ax1 = plt.subplot(1,3,1)
plt.plot(eta, sigma_c(eta,6,3), 'b--', label="$\sigma_c$")
plt.plot(eta, sigma_v(eta,6,3), 'r--', label="$\sigma_v$")
plt.plot(eta, sigma(eta,6,6,3), 'g-', label="$\sigma$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma(\sigma_0)$')
#plt.title('(a)')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(1,3,2)
plt.plot(eta, kappa_c(eta,6,3), 'b--', label="$\kappa_{e,c}$")
plt.plot(eta, kappa_v(eta,6,3), 'r--', label="$\kappa_{e,v}$")
plt.plot(eta, kappa(eta,6,6,3), 'g-', label="$\kappa_e$")
plt.axis([-8,8,0,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('n=6',fontsize=14)
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e(\kappa_0)$')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(1,3,3)
plt.plot(eta, S_c(eta,6,3), 'b--', label="$S_c$")
plt.plot(eta, S_v(eta,6,3), 'r--', label="$S_v$")
plt.plot(eta, S(eta,6,6,3), 'g-', label="$S$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S(S_0)$')
plt.legend(loc='upper right')
plt.tight_layout()

plt.savefig('figTESsigkap_6_3D.pdf')

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,2,5), 'b-', label="$n=2$")
plt.plot(eta, sigma(eta,4,4,5), 'r-', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma(\sigma_0)$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,2,5), 'b-', label="$n=2$")
plt.plot(eta, kappa(eta,4,4,5), 'r-', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,3]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e(\kappa_0)$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,2,5), 'b-', label="$n=2$")
plt.plot(eta, S(eta,4,4,5), 'r-', label="$n=4$")
plt.plot(eta, S(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,-6,6]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S(S_0)$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,2,5)**2*sigma(eta,2,2,5), 'b-')
plt.plot(eta,S(eta,4,4,5)**2*sigma(eta,4,4,5), 'r-')
plt.plot(eta,S(eta,6,6,5)**2*sigma(eta,6,6,5), 'g-')
plt.axis([-8,8,0,2])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF(S_0^2 \sigma_0)$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,2,5,0), 'b-', label="$n=2$")
ax5.plot(eta, ZT(eta,4,4,5,0), 'r-', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,5,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,8]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b-',label="$n=2$")
ax6.plot(eta,fil+20,'r-',label="$n=4$")
ax6.plot(eta,fil+20,'g-',label="$n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_n_3D_Delta=5.pdf')

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,6,3), 'b--', label="$n=2$")
plt.plot(eta, sigma(eta,4,6,3), 'r:', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma(\sigma_0)$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,6,3), 'b--', label="$n=2$")
plt.plot(eta, kappa(eta,4,6,3), 'r:', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e(\kappa_0)$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,6,3), 'b--', label="$n=2$")
plt.plot(eta, S(eta,4,6,3), 'r:', label="$n=4$")
plt.plot(eta, S(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,-6,6]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S(S_0)$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,6,3)**2*sigma(eta,2,6,3), 'b--')
plt.plot(eta,S(eta,4,6,3)**2*sigma(eta,4,6,3), 'r:')
plt.plot(eta,S(eta,6,6,3)**2*sigma(eta,6,6,3), 'g-')
plt.axis([-8,8,0,2])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF (S_0^2 \sigma_0)$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,6,3,0), 'b--', label="$n=2$")
ax5.plot(eta, ZT(eta,4,6,3,0), 'r:', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,3,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,6]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b--',label="$m=2,n=6$")
ax6.plot(eta,fil+20,'r:',label="$m=4,n=6$")
ax6.plot(eta,fil+20,'g-',label="$m=6,n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_ncomb_3D_Delta=3.pdf')

# %%
plt.figure(figsize=(10,3))
#plt.suptitle('m=2,n=6',fontsize=14)

ax1 = plt.subplot(1,3,1)
plt.plot(eta, sigma_c(eta,2,3), 'b--', label="$\sigma_c$")
plt.plot(eta, sigma_v(eta,6,3), 'r--', label="$\sigma_v$")
plt.plot(eta, sigma(eta,2,6,3), 'g-', label="$\sigma$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma (\sigma_0)$')
#plt.title('(a)')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(1,3,2)
plt.plot(eta, kappa_c(eta,2,3), 'b--', label="$\kappa_{e,c}$")
plt.plot(eta, kappa_v(eta,6,3), 'r--', label="$\kappa_{e,v}$")
plt.plot(eta, kappa(eta,2,6,3), 'g-', label="$\kappa_e$")
plt.axis([-8,8,0,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('m=2,n=6',fontsize=14)
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e (\kappa_0)$')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(1,3,3)
plt.plot(eta, S_c(eta,2,3), 'b--', label="$S_c$")
plt.plot(eta, S_v(eta,6,3), 'r--', label="$S_v$")
plt.plot(eta, S(eta,2,6,3), 'g-', label="$S$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S (S_0)$')
plt.legend(loc='upper right')
plt.tight_layout()

plt.savefig('figTESsigkap_combo2_3D.pdf')

# %%
plt.figure(figsize=(10,3))
#plt.suptitle('m=2,n=6',fontsize=14)

ax1 = plt.subplot(1,3,1)
plt.plot(eta, sigma_c(eta,4,3), 'b--', label="$\sigma_c$")
plt.plot(eta, sigma_v(eta,6,3), 'r--', label="$\sigma_v$")
plt.plot(eta, sigma(eta,4,6,3), 'g-', label="$\sigma$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma (\sigma_0)$')
#plt.title('(a)')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(1,3,2)
plt.plot(eta, kappa_c(eta,4,3), 'b--', label="$\kappa_{e,c}$")
plt.plot(eta, kappa_v(eta,6,3), 'r--', label="$\kappa_{e,v}$")
plt.plot(eta, kappa(eta,4,6,3), 'g-', label="$\kappa_e$")
plt.axis([-8,8,0,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('m=4,n=6',fontsize=14)
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e (\kappa_0)$')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(1,3,3)
plt.plot(eta, S_c(eta,4,3), 'b--', label="$S_c$")
plt.plot(eta, S_v(eta,6,3), 'r--', label="$S_v$")
plt.plot(eta, S(eta,4,6,3), 'g-', label="$S$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S (S_0)$')
plt.legend(loc='upper right')
plt.tight_layout()

plt.savefig('figTESsigkap_combo4_3D.pdf')

# %%
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,6,5), 'b--', label="$n=2$")
plt.plot(eta, sigma(eta,4,6,5), 'r:', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma (\sigma_0)$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,6,5), 'b--', label="$n=2$")
plt.plot(eta, kappa(eta,4,6,5), 'r:', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,3]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e (\kappa_0)$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,6,5), 'b--', label="$n=2$")
plt.plot(eta, S(eta,4,6,5), 'r:', label="$n=4$")
plt.plot(eta, S(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,-8,8]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S (S_0)$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,6,5)**2*sigma(eta,2,6,5), 'b--')
plt.plot(eta,S(eta,4,6,5)**2*sigma(eta,4,6,5), 'r:')
plt.plot(eta,S(eta,6,6,5)**2*sigma(eta,6,6,5), 'g-')
plt.axis([-8,8,0,2])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF  (S_0^2 \sigma_0)$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,6,5,0), 'b--', label="$n=2$")
ax5.plot(eta, ZT(eta,4,6,5,0), 'r:', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,5,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,11]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b--',label="$m=2,n=6$")
ax6.plot(eta,fil+20,'r:',label="$m=4,n=6$")
ax6.plot(eta,fil+20,'g-',label="$m=6,n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_ncomb_3D_Delta=5.pdf')

# %%
plt.figure(figsize=(10,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, S(eta,2,2,3)**2*sigma(eta,2,2,3), 'b--', label="$n=2$")
plt.plot(eta, S(eta,4,4,3)**2*sigma(eta,4,4,3), 'r:', label="$n=4$")
plt.plot(eta, S(eta,6,6,3)**2*sigma(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF (S_0^2 \sigma_0)$')
plt.title('$\Delta=3 k_B T$')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, S(eta,2,2,5)**2*sigma(eta,2,2,5), 'b--', label="$n=2$")
plt.plot(eta, S(eta,4,4,5)**2*sigma(eta,4,4,5), 'r:', label="$n=4$")
plt.plot(eta, S(eta,6,6,5)**2*sigma(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('$\Delta=5 k_B T$')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF (S_0^2 \sigma_0)$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,2,7)**2*sigma(eta,2,2,7), 'b--', label="$n=2$")
plt.plot(eta, S(eta,4,4,7)**2*sigma(eta,4,4,7), 'r:', label="$n=4$")
plt.plot(eta, S(eta,6,6,7)**2*sigma(eta,6,6,7), 'g-', label="$n=6$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('$\Delta=7k_B T$')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF (S_0^2 \sigma_0)$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
ax4.plot(eta, ZT(eta,2,2,3,0), 'b--', label="$n=2$")
ax4.plot(eta, ZT(eta,4,4,3,0), 'r:', label="$n=4$")
ax4.plot(eta, ZT(eta,6,6,3,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,15]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
#plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,2,5,0), 'b--', label="$n=2$")
ax5.plot(eta, ZT(eta,4,4,5,0), 'r:', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,5,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,15]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
#plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
ax6.plot(eta, ZT(eta,2,2,7,0), 'b--', label="$n=2$")
ax6.plot(eta, ZT(eta,4,4,7,0), 'r:', label="$n=4$")
ax6.plot(eta, ZT(eta,6,6,7,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,15]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.legend(bbox_to_anchor=(1.1,1))
#plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

plt.savefig('figTEPFandZT_3D_Delta.pdf')

# %%
plt.figure(figsize=(9,3))

ax1 = plt.subplot(1,3,1)
plt.plot(eta, ZT(eta,2,2,3,0), 'k--', label="$\alpha=0$")
plt.plot(eta, ZT(eta,2,2,3,1), 'b-', label="$\alpha=1$")
plt.plot(eta, ZT(eta,2,2,3,5), 'r-', label="$\alpha=5$")
plt.plot(eta, ZT(eta,2,2,3,10), 'g-', label="$\alpha=10$")
plt.axis([-8,8,0,3]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.xlabel('$\mu/k_B T$')
plt.text(2.5,2.2, r'$\alpha=1$', color='b')
plt.text(2.1,1.2, r'$\alpha=5$', color='r')
plt.text(2.5,0.3, r'$\alpha=10$', color='g')
plt.text(3.0,2.8, r'$\alpha=0$', color='k')
plt.title('n=2',fontsize=14)
plt.ylabel('$ZT$')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

ax2 = plt.subplot(1,3,2)
plt.plot(eta, ZT(eta,4,4,3,0), 'k--', label="$\alpha=0$")
plt.plot(eta, ZT(eta,4,4,3,1), 'b-', label="$\alpha=1$")
plt.plot(eta, ZT(eta,4,4,3,5), 'r-', label="$\alpha=5$")
plt.plot(eta, ZT(eta,4,4,3,10), 'g-', label="$\alpha=10$")
plt.axis([-8,8,0,3]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('n=4',fontsize=14)
plt.xlabel('$\mu/k_B T$')
#plt.ylabel('$ZT$')
plt.tight_layout()

ax3 = plt.subplot(1,3,3)
plt.plot(eta, ZT(eta,6,6,3,0), 'k--', label="$\alpha=0$")
plt.plot(eta, ZT(eta,6,6,3,1), 'b-', label="$\alpha=1$")
plt.plot(eta, ZT(eta,6,6,3,5), 'r-', label="$\alpha=5$")
plt.plot(eta, ZT(eta,6,6,3,10), 'g-', label="$\alpha=10$")
plt.axis([-8,8,0,3]) # the format is [xmin,xmax,ymin,ymax]
plt.title('n=6',fontsize=14)
# in plt.xlabel or ylabel, the option r is not necessary
#plt.xlabel('$\mu/k_B T$')
#plt.ylabel('$ZT$')
plt.tight_layout()

#plt.savefig('figTEZT_n_alpha_Delta=3_3D.pdf')

# %%
plt.figure(figsize=(11,3))
limas = zeros(npoint)
limas = limas+3

ax1 = plt.subplot(1,3,1)
#plt.plot(eta, ZT(eta,2,4,3,5*C2), 'k--', label="$\alpha=0$")
plt.plot(eta, ZT(eta,2,6,3,1/3), 'b--', label="$\alpha=1$")
plt.plot(eta, ZT(eta,4,6,3,1/3), 'r--', label="$\alpha=5$")
plt.plot(eta, ZT(eta,6,6,3,1/3), 'g-', label="$\alpha=10$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.xlabel('$\mu/k_B T$')
#ax1.xaxis.set_minor_locator(AutoMinorLocator(5))
plt.ylabel('$ZT$')
plt.title('$\Delta=3k_B T$', fontsize=14)
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

limas=limas+2
ax2 = plt.subplot(1,3,2)
#plt.plot(eta, ZT(eta,2,4,3,5*C2), 'k--', label="$\alpha=0$")
plt.plot(eta, ZT(eta,2,6,5,1/3), 'b--', label="$\alpha=1$")
plt.plot(eta, ZT(eta,4,6,5,1/3), 'r--', label="$\alpha=5$")
plt.plot(eta, ZT(eta,6,6,5,1/3), 'g-', label="$\alpha=10$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.title('$\Delta=5k_B T$', fontsize=14)
#plt.ylabel('$ZT$')
plt.tight_layout()

ax3 = plt.subplot(1,3,3)
#plt.plot(eta, ZT(eta,2,4,3,5*C2), 'k--', label="$\alpha=0$")
plt.plot(eta, ZT(eta,2,6,7,1/3), 'b--', label="$m=2,n=6$")
plt.plot(eta, ZT(eta,4,6,7,1/3), 'r--', label="$m=4,n=6$")
plt.plot(eta, ZT(eta,6,6,7,1/3), 'g-', label="$m=6,n=6$")
plt.axis([-8,8,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.xlabel('$\mu/k_B T$')
#plt.ylabel('$ZT$')
plt.legend(bbox_to_anchor=(1.1,1))
plt.title('$\Delta=7k_B T$', fontsize=14)
plt.tight_layout()

#plt.savefig('figTEZT_ncombo_Delta_3D.pdf')

# %%
plt.plot(eta,ZT(eta,6,6,8,0))
plt.plot(eta,ZT(eta,6,6,8,1/3))
#plt.ylim([0,4])

# %%
from numpy import argmax

npoint = 201
eta = linspace(-10, 10, npoint) 

ndelta = 40
delta = linspace(0, 20, ndelta) 

eta = linspace(-19.99, 20.01, npoint)

def ZTemax(x,m,n,alpha):
    zt = zeros(ndelta)
    for i in range(delta.size):
        emax[i] = argmax(ZT(eta,m,n,x[i],0))
        zt[i] = ZT(eta,m,n,x[i],alpha)[emax]
    return zt
    
ZT22 = ZTemax(delta,2,2,1/3)
ZT24 = ZTemax(delta,2,4,1/3)
ZT26 = ZTemax(delta,2,6,1/3)
ZT44 = ZTemax(delta,4,4,1/3)
ZT66 = ZTemax(delta,6,6,1/3)
ZT46 = ZTemax(delta,4,6,1/3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c31749cf304a> in <module>
#      16     return zt
#      17
# ---> 18 ZT22 = ZTemax(delta,2,2,1/3)
#      19 ZT24 = ZTemax(delta,2,4,1/3)
#      20 ZT26 = ZTemax(delta,2,6,1/3)
#
# <ipython-input-4-c31749cf304a> in ZTemax(x, m, n, alpha)
#      12     zt = zeros(ndelta)
#      13     for i in range(delta.size):
# ---> 14         emax[i] = argmax(ZT(eta,m,n,x[i],0))
#      15         zt[i] = ZT(eta,m,n,x[i],alpha)[emax]
#      16     return zt
#
# NameError: name 'emax' is not defined

# %%
ZT22p = ZTemax(delta,2,2,10/3)
ZT24p = ZTemax(delta,2,4,10/3)
ZT26p = ZTemax(delta,2,6,10/3)
ZT44p = ZTemax(delta,4,4,10/3)
ZT66p = ZTemax(delta,6,6,10/3)
ZT46p = ZTemax(delta,4,6,10/3)

# %%
#Finding optimal bandgap
from numpy import argmax

npoint = 201
eta = linspace(-10, 10, npoint) 

ndelta = 40
delta = linspace(0, 20, ndelta) 

eta = linspace(-19.99, 20.01, npoint)

def ZTmax(x,m,n,alpha):
    zt = zeros(ndelta)
    emax = zeros(ndelta)
    for i in range(delta.size):
        emax[i] = argmax(ZT(eta,m,n,x[i],alpha))
        zt[i] = max(ZT(eta,m,n,x[i],alpha))
    return zt, emax

ZT22,eta22=ZTmax(delta,2,2,1/3)
ZT24,eta24=ZTmax(delta,2,4,1/3)
ZT26,eta26=ZTmax(delta,2,6,1/3)
ZT46,eta46=ZTmax(delta,4,6,1/3)
ZT44,eta44=ZTmax(delta,4,4,1/3)
ZT66,eta66=ZTmax(delta,6,6,1/3)

# %%
ZT22p,eta22p=ZTmax(delta,2,2,10/3)
ZT24p,eta24p=ZTmax(delta,2,4,10/3)
ZT26p,eta26p=ZTmax(delta,2,6,10/3)
ZT46p,eta46p=ZTmax(delta,4,6,10/3)
ZT44p,eta44p=ZTmax(delta,4,4,10/3)
ZT66p,eta66p=ZTmax(delta,6,6,10/3)

# %%
plt.figure(figsize=(12,4))

ax1 = plt.subplot(1,2,1)
plt.plot(delta,ZT22, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24, 'b--', label="$m=2,n=4$")
#plt.plot(delta,ZT26, 'b--', label="$m=2,n=6$")
plt.plot(delta,ZT44, 'r-', label="$m=4,n=4$")
#plt.plot(delta,ZT46, 'r--', label="$m=4,n=6$")
plt.plot(delta,ZT66, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.ylim([0,3])
plt.xlabel('$\Delta/k_B T$')
plt.ylabel('$ZT_{max}$')
plt.title('$\kappa_{ph} = \kappa_0/3$',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax2 = plt.subplot(1,2,2)
#plt.plot(delta,ZT22p, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24p, 'b--', label="$m=2,n=4$")
#plt.plot(delta,ZT26p, 'b--', label="$m=2,n=6$")
#plt.plot(delta,ZT44p, 'r-', label="$m=4,n=4$")
#plt.plot(delta,ZT46p, 'r--', label="$m=4,n=6$")
#plt.plot(delta,ZT66p, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('$\kappa_{ph} = (10/3)\kappa_0$',fontsize=14)
plt.xlabel('$\Delta/k_B T$')
#plt.ylabel('$ZT_{max}$')
plt.legend(bbox_to_anchor=(1.6,1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()
#plt.savefig('FigZTvsDelta_new_sym_3D.pdf')
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(12,4))

ax1 = plt.subplot(1,2,1)
#plt.plot(delta,ZT22, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24, 'b--', label="$m=2,n=4$")
plt.plot(delta,ZT26, 'b--', label="$m=2,n=6$")
#plt.plot(delta,ZT44, 'r-', label="$m=4,n=4$")
plt.plot(delta,ZT46, 'r:', label="$m=4,n=6$")
plt.plot(delta,ZT66, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\Delta/k_B T$')
plt.ylabel('$ZT_{max}$')
plt.title('$\kappa_{ph} = \kappa_0/3$',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax2 = plt.subplot(1,2,2)
#plt.plot(delta,ZT22p, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24p, 'b--', label="$m=2,n=4$")
plt.plot(delta,ZT26p, 'b--', label="$m=2,n=6$")
#plt.plot(delta,ZT44p, 'r-', label="$m=4,n=4$")
plt.plot(delta,ZT46p, 'r:', label="$m=4,n=6$")
plt.plot(delta,ZT66p, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('$\kappa_{ph} = (10/3)\kappa_0$',fontsize=14)
plt.xlabel('$\Delta/k_B T$')
#plt.ylabel('$ZT_{max}$')
plt.legend(bbox_to_anchor=(1.6,1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()
plt.savefig('FigZTvsDelta_new_comb_3D.pdf')

# %%
plog = frompyfunc(polylog, 2, 1)

def F0(x):
    return exp(x)/(1+exp(x))
def F1(x):
    return ( x/(1+exp(x)) + log(1+exp(-x)) )
def F2(x):
    return ( (pi**2)/3 - (x**2 / (1+exp(x)) )
            - 2*x*log(1+exp(-x)) + 2*plog(2,-exp(-x)) )
def F3(x):
    return ( (x**3)/(1+exp(x)) + 3*(x**2)*log(1+exp(-x)) - 6*x*plog(2,-exp(-x)) - 6*plog(3,-exp(-x)) )

def F0v(x):
    return 1/(1+exp(x))
def F1v(x):
    return ( x/(1+exp(-x)) - log(1+exp(x)) )
def F2v(x):
    return ( (x**2 / (1+exp(x)) ) + 2*x*log(1+exp(-x))
            - 2*plog(2,-exp(-x)) )
def F3v(x):
     return ( -(x**3)/(1+exp(x)) - 3*(x**2)*log(1+exp(-x)) + 6*x*plog(2,-exp(-x)) + 6*plog(3,-exp(-x)) )

def L0c(x,D):
    return F1(x-D)+(x-D)*F0(x-D)

def L1c(x,D):
    return F2(x-D)+(x-D)*F1(x-D)

def L2c(x,D):
    return F3(x-D)+(x-D)*F2(x-D)

def L0v(x,D):
    return -(-F1(-x-D)+(x+D)*F0(-x-D))

def L1v(x,D):
    return -(F2(-x-D)-(x+D)*F1(-x-D))

def L2v(x,D):
    return -(-F3(x+D)+(x+D)*F2(-x-D))


# Create sample points within [-10,10]:
npoint = 201
eta = linspace(-10, 10, npoint) 

#define thermoelectric coefficients
def S_c(x,n,W):
    sc = zeros(x.size)
    for i in range(x.size):
        sc[i] = -L1c(x[i],W)/L0c(x[i],W)
    return sc

def sigma_c(x,n,W):
    sgm = zeros(x.size)
    for i in range(x.size):
        sgm[i] = n*C2*L0c(x[i],W)
    return sgm

def kappa_c(x,n,W):
    kpp = zeros(x.size)
    for i in range(x.size):
        kpp[i] = n*C2*(L2c(x[i],W)-(L1c(x[i],W)**2/L0c(x[i],W)))
    return kpp

def S_v(x,n,W):
    sc = zeros(x.size)
    for i in range(x.size):
        sc[i] = -L1v(x[i],W)/L0v(x[i],W)
    return sc

def sigma_v(x,n,W):
    sgm = zeros(x.size)
    for i in range(x.size):
        sgm[i] = n*C2*L0v(x[i],W)
    return sgm

def kappa_v(x,n,W):
    kpp = zeros(x.size)
    for i in range(x.size):
        kpp[i] = n*C2*(L2v(x[i],W)-(L1v(x[i],W)**2/L0v(x[i],W)))
    return kpp

def sigma(x,m,n,W):
    return sigma_c(x,m,W)+sigma_v(x,n,W)

def S(x,m,n,W):
    return (sigma_c(x,m,W)*S_c(x,m,W)+sigma_v(x,n,W)*S_v(x,n,W))/sigma(x,m,n,W)

def kappa(x,m,n,W):
    return kappa_c(x,m,W)+kappa_v(x,n,W)+(sigma_c(x,m,W)*sigma_v(x,n,W)*(S_c(x,m,W)-S_v(x,n,W))**2)/sigma(x,m,n,W)


def PF(Sc,Sgm):
    return (Sc**2)*Sgm

def ZT(x,m,n,W,alpha):
    return (S(x,m,n,W)**2 * sigma(x,m,n,W))/(kappa(x,m,n,W) + alpha)

# %%
ZT2D22Delta3 = ZT(eta,2,2,3,0)
ZT2D44Delta3 = ZT(eta,4,4,3,0)
ZT2D66Delta3 = ZT(eta,6,6,3,0)
ZT2D22Delta5 = ZT(eta,2,2,5,0)
ZT2D44Delta5 = ZT(eta,4,4,5,0)
ZT2D66Delta5 = ZT(eta,6,6,5,0)

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,2,3), 'b-', label="$n=2$")
plt.plot(eta, sigma(eta,4,4,3), 'r-', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,2.5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,2,3), 'b-', label="$n=2$")
plt.plot(eta, kappa(eta,4,4,3), 'r-', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,6]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,2,3), 'b-', label="$n=2$")
plt.plot(eta, S(eta,4,4,3), 'r-', label="$n=4$")
plt.plot(eta, S(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,2,3)**2*sigma(eta,2,2,3), 'b-')
plt.plot(eta,S(eta,4,4,3)**2*sigma(eta,4,4,3), 'r-')
plt.plot(eta,S(eta,6,6,3)**2*sigma(eta,6,6,3), 'g-')
plt.axis([-8,8,0,2.5])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,2,3,0), 'b-', label="$n=2$")
ax5.plot(eta, ZT(eta,4,4,3,0), 'r-', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,3,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b-',label="$n=2$")
ax6.plot(eta,fil+20,'r-',label="$n=4$")
ax6.plot(eta,fil+20,'g-',label="$n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_n_2D.pdf')

# %%
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,6,3), 'b--', label="$n=2$")
plt.plot(eta, sigma(eta,4,6,3), 'r:', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,2.5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,6,3), 'b--', label="$n=2$")
plt.plot(eta, kappa(eta,4,6,3), 'r:', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,6]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,6,3), 'b--', label="$n=2$")
plt.plot(eta, S(eta,4,6,3), 'r:', label="$n=4$")
plt.plot(eta, S(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,6,3)**2*sigma(eta,2,6,3), 'b--')
plt.plot(eta,S(eta,4,6,3)**2*sigma(eta,4,6,3), 'r:')
plt.plot(eta,S(eta,6,6,3)**2*sigma(eta,6,6,3), 'g-')
plt.axis([-8,8,0,2.5])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,6,3,0), 'b--', label="$n=2$")
ax5.plot(eta, ZT(eta,4,6,3,0), 'r:', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,3,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b--',label="$m=2,n=6$")
ax6.plot(eta,fil+20,'r:',label="$m=4,n=6$")
ax6.plot(eta,fil+20,'g-',label="$m=6,n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_ncomb_2D.pdf')

# %%
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,2,5), 'b-', label="$n=2$")
plt.plot(eta, sigma(eta,4,4,5), 'r-', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,1.5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,2,5), 'b-', label="$n=2$")
plt.plot(eta, kappa(eta,4,4,5), 'r-', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,2,5), 'b-', label="$n=2$")
plt.plot(eta, S(eta,4,4,5), 'r-', label="$n=4$")
plt.plot(eta, S(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,-6,6]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,2,5)**2*sigma(eta,2,2,5), 'b-')
plt.plot(eta,S(eta,4,4,5)**2*sigma(eta,4,4,5), 'r-')
plt.plot(eta,S(eta,6,6,5)**2*sigma(eta,6,6,5), 'g-')
plt.axis([-8,8,0,2.5])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,2,5,0), 'b-', label="$n=2$")
ax5.plot(eta, ZT(eta,4,4,5,0), 'r-', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,5,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,8]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b-',label="$n=2$")
ax6.plot(eta,fil+20,'r-',label="$n=4$")
ax6.plot(eta,fil+20,'g-',label="$n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_n_2D_Delta=5.pdf')

# %%
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,6,5), 'b--', label="$n=2$")
plt.plot(eta, sigma(eta,4,6,5), 'r:', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,1.5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,6,5), 'b--', label="$n=2$")
plt.plot(eta, kappa(eta,4,6,5), 'r:', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,6,5), 'b--', label="$n=2$")
plt.plot(eta, S(eta,4,6,5), 'r:', label="$n=4$")
plt.plot(eta, S(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,-6,6]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,6,5)**2*sigma(eta,2,6,5), 'b--')
plt.plot(eta,S(eta,4,6,5)**2*sigma(eta,4,6,5), 'r:')
plt.plot(eta,S(eta,6,6,5)**2*sigma(eta,6,6,5), 'g-')
plt.axis([-8,8,0,2.5])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,6,5,0), 'b--', label="$n=2$")
ax5.plot(eta, ZT(eta,4,6,5,0), 'r:', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,5,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,9]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b--',label="$m=2,n=6$")
ax6.plot(eta,fil+20,'r:',label="$m=4,n=6$")
ax6.plot(eta,fil+20,'g-',label="$m=6,n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_ncomb_2D_Delta=5.pdf')

# %%
ndelta = 40
delta = linspace(0, 20, ndelta) 

eta = linspace(-19.99, 20.01, npoint)

def ZTmax(x,m,n,alpha):
    zt = zeros(ndelta)
    emax = zeros(ndelta)
    for i in range(delta.size):
        emax[i] = argmax(ZT(eta,m,n,x[i],alpha))
        zt[i] = max(ZT(eta,m,n,x[i],alpha))
    return zt,emax

ZT22_2,eta22_2=ZTmax(delta,2,2,1/3)
ZT24_2,eta24_2=ZTmax(delta,2,4,1/3)
ZT26_2,eta26_2=ZTmax(delta,2,6,1/3)
ZT46_2,eta46_2=ZTmax(delta,4,6,1/3)
ZT44_2,eta44_2=ZTmax(delta,4,4,1/3)
ZT66_2,eta66_2=ZTmax(delta,6,6,1/3)

# %%
ZT22p_2,eta22p_2=ZTmax(delta,2,2,10/3)
ZT24p_2,eta24p_2=ZTmax(delta,2,4,10/3)
ZT26p_2,eta26p_2=ZTmax(delta,2,6,10/3)
ZT46p_2,eta46p_2=ZTmax(delta,4,6,10/3)
ZT44p_2,eta44p_2=ZTmax(delta,4,4,10/3)
ZT66p_2,eta66p_2=ZTmax(delta,6,6,10/3)

# %%
plt.figure(figsize=(12,4))

ax1 = plt.subplot(1,2,1)
plt.plot(delta,ZT22_2, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24_2, 'b--', label="$m=2,n=4$")
#plt.plot(delta,ZT26_2, 'b--', label="$m=2,n=6$")
plt.plot(delta,ZT44_2, 'r-', label="$m=4,n=4$")
#plt.plot(delta,ZT46, 'r--', label="$m=4,n=6$")
plt.plot(delta,ZT66_2, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,2.5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\Delta/k_B T$')
plt.ylabel('$ZT_{max}$')
plt.title('$\kappa_{ph} = \kappa_0/3$',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax2 = plt.subplot(1,2,2)
plt.plot(delta,ZT22p_2, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24p, 'b--', label="$m=2,n=4$")
#plt.plot(delta,ZT26p, 'b--', label="$m=2,n=6$")
plt.plot(delta,ZT44p_2, 'r-', label="$m=4,n=4$")
#plt.plot(delta,ZT46p, 'r--', label="$m=4,n=6$")
plt.plot(delta,ZT66p_2, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,2.5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('$\kappa_{ph} = (10/3)\kappa_0$',fontsize=14)
plt.xlabel('$\Delta/k_B T$')
#plt.ylabel('$ZT_{max}$')
plt.legend(bbox_to_anchor=(1.6,1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()
plt.savefig('FigZTvsDelta_new_sym_2D.pdf')

# %%
plt.figure(figsize=(12,4))

ax1 = plt.subplot(1,2,1)
#plt.plot(delta,ZT22, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24, 'b--', label="$m=2,n=4$")
plt.plot(delta,ZT26_2, 'b--', label="$m=2,n=6$")
#plt.plot(delta,ZT44, 'r-', label="$m=4,n=4$")
plt.plot(delta,ZT46_2, 'r:', label="$m=4,n=6$")
plt.plot(delta,ZT66_2, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,2.5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\Delta/k_B T$')
plt.ylabel('$ZT_{max}$')
plt.title('$\kappa_{ph} = \kappa_0/3$',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax2 = plt.subplot(1,2,2)
#plt.plot(delta,ZT22p, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24p, 'b--', label="$m=2,n=4$")
plt.plot(delta,ZT26p_2, 'b--', label="$m=2,n=6$")
#plt.plot(delta,ZT44p, 'r-', label="$m=4,n=4$")
plt.plot(delta,ZT46p_2, 'r:', label="$m=4,n=6$")
plt.plot(delta,ZT66p_2, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,2.5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('$\kappa_{ph} = (10/3)\kappa_0$',fontsize=14)
plt.xlabel('$\Delta/k_B T$')
#plt.ylabel('$ZT_{max}$')
plt.legend(bbox_to_anchor=(1.6,1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()
plt.savefig('FigZTvsDelta_new_comb_2D.pdf')

# %%
infty = 100
kT_A  = 0.013   #Boltzmann constant times temperature
a = pi        #Normalization factor A
C1 = 1/pi
C2 = 1/(4*pi)
C3 = 1/(6*pi*pi)
kph = a*(kT_A)


# Define kernel:
def L0c(xx,N,D):
    def integrand (x,xx):
        return (x+xx-D)**((-1+N)/N) * (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, D-xx, infty, args=(xx))
    return N*C1*((kT_A)**(-1/N)/a)*I

def L1c(xx,N,D):
    def integrand (x,xx):
        return (x+xx-D)**((-1+N)/N)*x* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, D-xx, infty, args=(xx))
    return N*C1*((kT_A)**(-1/N)/a)*I

def L2c(xx,N,D):
    def integrand (x,xx):
        return (x+xx-D)**((-1+N)/N) * (x**2)* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, D-xx, infty, args=(xx))
    return N*C1*((kT_A)**(-1/N)/a)*I

def L0v(xx,N,D):
    def integrand (x,xx):
        return (-x-xx-D)**((-1+N)/N) * (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, -infty, -D-xx, args=(xx))
    return N*C1*((kT_A)**(-1/N)/a)*I

def L1v(xx,N,D):
    def integrand (x,xx):
        return (-x-xx-D)**((-1+N)/N)*x* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, -infty, -D-xx, args=(xx))
    return N*C1*((kT_A)**(-1/N)/a)*I

def L2v(xx,N,D):
    def integrand (x,xx):
        return (-x-xx-D)**((-1+N)/N) * (x**2)* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, -infty, -D-xx, args=(xx))
    return N*C1*((kT_A)**(-1/N)/a)*I

def S_c(x,n,W):
    sc = zeros(x.size)
    for i in range(x.size):
        sc[i] = -L1c(x[i],n,W)/L0c(x[i],n,W)
    return sc

def sigma_c(x,n,W):
    sgm = zeros(x.size)
    for i in range(x.size):
        sgm[i] = L0c(x[i],n,W)
    return sgm

def kappa_c(x,n,W):
    kpp = zeros(x.size)
    for i in range(x.size):
        kpp[i] = (L2c(x[i],n,W)-(L1c(x[i],n,W)**2/L0c(x[i],n,W)))
    return kpp

def S_v(x,n,W):
    sc = zeros(x.size)
    for i in range(x.size):
        sc[i] = -L1v(x[i],n,W)/L0v(x[i],n,W)
    return sc

def sigma_v(x,n,W):
    sgm = zeros(x.size)
    for i in range(x.size):
        sgm[i] = L0v(x[i],n,W)
    return sgm

def kappa_v(x,n,W):
    kpp = zeros(x.size)
    for i in range(x.size):
        kpp[i] = (L2v(x[i],n,W)-(L1v(x[i],n,W)**2/L0v(x[i],n,W)))
    return kpp

def sigma(x,m,n,W):
    return sigma_c(x,m,W)+sigma_v(x,n,W)

def S(x,m,n,W):
    return (sigma_c(x,m,W)*S_c(x,m,W)+sigma_v(x,n,W)*S_v(x,n,W))/sigma(x,m,n,W)

def kappa(x,m,n,W):
    return kappa_c(x,m,W)+kappa_v(x,n,W)+(sigma_c(x,m,W)*sigma_v(x,n,W)*(S_c(x,m,W)-S_v(x,n,W))**2)/sigma(x,m,n,W)


def PF(Sc,Sgm):
    return (Sc**2)*Sgm

def ZT(x,m,n,W,alpha):
    return (S(x,m,n,W)**2 * sigma(x,m,n,W))/(kappa(x,m,n,W) + alpha)

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,2,3), 'b-', label="$n=2$")
plt.plot(eta, sigma(eta,4,4,3), 'r-', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma (\sigma_0)$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,2,3), 'b-', label="$n=2$")
plt.plot(eta, kappa(eta,4,4,3), 'r-', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,9]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e (\kappa_0)$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,2,3), 'b-', label="$n=2$")
plt.plot(eta, S(eta,4,4,3), 'r-', label="$n=4$")
plt.plot(eta, S(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S (S_0)$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,2,3)**2*sigma(eta,2,2,3), 'b-')
plt.plot(eta,S(eta,4,4,3)**2*sigma(eta,4,4,3), 'r-')
plt.plot(eta,S(eta,6,6,3)**2*sigma(eta,6,6,3), 'g-')
plt.axis([-8,8,0,4])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF (S_0^2 \sigma_0)$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,2,3,0), 'b-', label="$n=2$")
ax5.plot(eta, ZT(eta,4,4,3,0), 'r-', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,3,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b-',label="$n=2$")
ax6.plot(eta,fil+20,'r-',label="$n=4$")
ax6.plot(eta,fil+20,'g-',label="$n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_n_1D.pdf')

# %%
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,6,3), 'b--', label="$n=2$")
#plt.plot(eta, sigma(eta,2,4,3), 'r--', label="$n=2$")
plt.plot(eta, sigma(eta,4,6,3), 'r:', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma (\sigma_0)$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,6,3), 'b--', label="$n=2$")
#plt.plot(eta, kappa(eta,2,4,3), 'r--', label="$n=2$")
plt.plot(eta, kappa(eta,4,6,3), 'r:', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,0,9]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e (\kappa_0)$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,6,3), 'b--', label="$n=2$")
#plt.plot(eta, S(eta,2,4,3), 'r--', label="$n=2$")
plt.plot(eta, S(eta,4,6,3), 'r:', label="$n=4$")
plt.plot(eta, S(eta,6,6,3), 'g-', label="$n=6$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S (S_0)$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,6,3)**2*sigma(eta,2,6,3), 'b--')
#plt.plot(eta,S(eta,2,4,3)**2*sigma(eta,2,4,3), 'r--')
plt.plot(eta,S(eta,4,6,3)**2*sigma(eta,4,6,3), 'r:')
plt.plot(eta,S(eta,6,6,3)**2*sigma(eta,6,6,3), 'g-')
plt.axis([-8,8,0,4])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF (S_0^2 \sigma_0)$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,6,3,0), 'b--', label="$n=2$")
#ax5.plot(eta, ZT(eta,2,4,3,0), 'r--', label="$n=2$")
ax5.plot(eta, ZT(eta,4,6,3,0), 'r:', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,3,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b--',label="$m=2,n=6$")
#ax6.plot(eta,fil+20,'r--',label="$m=2,n=4$")
ax6.plot(eta,fil+20,'r:',label="$m=4,n=6$")
ax6.plot(eta,fil+20,'g-',label="$m=6,n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_ncomb_1D.pdf')

# %%
plt.figure(figsize=(9,6))

ax1 = plt.subplot(2,3,1)
plt.plot(eta, sigma(eta,2,2,5), 'b-', label="$n=2$")
plt.plot(eta, sigma(eta,4,4,5), 'r-', label="$n=4$")
plt.plot(eta, sigma(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,3]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma (\sigma_0)$')
plt.title('(a)')
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(2,3,2)
plt.plot(eta, kappa(eta,2,2,5), 'b-', label="$n=2$")
plt.plot(eta, kappa(eta,4,4,5), 'r-', label="$n=4$")
plt.plot(eta, kappa(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,0,7]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('(b)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e (\kappa_0)$')
#plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(2,3,3)
plt.plot(eta, S(eta,2,2,5), 'b-', label="$n=2$")
plt.plot(eta, S(eta,4,4,5), 'r-', label="$n=4$")
plt.plot(eta, S(eta,6,6,5), 'g-', label="$n=6$")
plt.axis([-8,8,-6,6]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S (S_0)$')
#plt.legend(loc='upper right')
plt.tight_layout()

ax4 = plt.subplot(2,3,4)
plt.plot(eta,S(eta,2,2,5)**2*sigma(eta,2,2,5), 'b-')
plt.plot(eta,S(eta,4,4,5)**2*sigma(eta,4,4,5), 'r-')
plt.plot(eta,S(eta,6,6,5)**2*sigma(eta,6,6,5), 'g-')
plt.axis([-8,8,0,4])
plt.title('(d)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$PF (S_0^2 \sigma_0)$')
plt.tight_layout()

ax5 = plt.subplot(2,3,5)
ax5.plot(eta, ZT(eta,2,2,5,0), 'b-', label="$n=2$")
ax5.plot(eta, ZT(eta,4,4,5,0), 'r-', label="$n=4$")
ax5.plot(eta, ZT(eta,6,6,5,0), 'g-', label="$n=6$")
plt.axis([-8,8,0,8]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.7,1))
plt.title('(e)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$ZT_e$')
#plt.legend()
plt.tight_layout()

ax6 = plt.subplot(2,3,6)
fil = zeros(npoint)
ax6.plot(eta,fil+20,'b-',label="$n=2$")
ax6.plot(eta,fil+20,'r-',label="$n=4$")
ax6.plot(eta,fil+20,'g-',label="$n=6$")
ax6.axis([-1,1,0,1])
ax6.set_axis_off()
ax6.legend(loc='upper left',fontsize=14)

plt.savefig('figTEbase_n_1D_Delta=5.pdf')

# %%
ndelta = 40
delta = linspace(0, 20, ndelta) 

eta = linspace(-19.99, 20.01, npoint)

def ZTmax(x,m,n,alpha):
    zt = zeros(ndelta)
    emax = zeros(ndelta)
    for i in range(delta.size):
        emax[i] = argmax(ZT(eta,m,n,x[i],alpha))
        zt[i] = max(ZT(eta,m,n,x[i],alpha))
    return zt,emax

ZT22_1,eta22_1=ZTmax(delta,2,2,1/3)
ZT24_1,eta24_1=ZTmax(delta,2,4,1/3)
ZT26_1,eta26_1=ZTmax(delta,2,6,1/3)
ZT46_1,eta46_1=ZTmax(delta,4,6,1/3)
ZT44_1,eta44_1=ZTmax(delta,4,4,1/3)
ZT66_1,eta66_1=ZTmax(delta,6,6,1/3)

# %%
ZT22p_1,eta22p_1=ZTmax(delta,2,2,10/3)
ZT24p_1,eta24p_1=ZTmax(delta,2,4,10/3)
ZT26p_1,eta26p_1=ZTmax(delta,2,6,10/3)
ZT46p_1,eta46p_1=ZTmax(delta,4,6,10/3)
ZT44p_1,eta44p_1=ZTmax(delta,4,4,10/3)
ZT66p_1,eta66p_1=ZTmax(delta,6,6,10/3)

# %%
plt.figure(figsize=(12,4))

ax1 = plt.subplot(1,2,1)
plt.plot(delta,ZT22_1, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24, 'b--', label="$m=2,n=4$")
#plt.plot(delta,ZT26, 'b--', label="$m=2,n=6$")
plt.plot(delta,ZT44_1, 'r-', label="$m=4,n=4$")
#plt.plot(delta,ZT46, 'r--', label="$m=4,n=6$")
plt.plot(delta,ZT66_1, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\Delta/k_B T$')
plt.ylabel('$ZT_{max}$')
plt.title('$\kappa_{ph} = \kappa_0/3$',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax2 = plt.subplot(1,2,2)
plt.plot(delta,ZT22p_1, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24p, 'b--', label="$m=2,n=4$")
#plt.plot(delta,ZT26p, 'b--', label="$m=2,n=6$")
plt.plot(delta,ZT44p_1, 'r-', label="$m=4,n=4$")
#plt.plot(delta,ZT46p, 'r--', label="$m=4,n=6$")
plt.plot(delta,ZT66p_1, 'g-', label="$m=6,n=6$")
plt.axis([0,10,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('$\kappa_{ph} = (10/3)\kappa_0$',fontsize=14)
plt.xlabel('$\Delta/k_B T$')
#plt.ylabel('$ZT_{max}$')
plt.legend(bbox_to_anchor=(1.6,1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()
plt.savefig('FigZTvsDelta_new_sym_1D.pdf')

# %%
plt.figure(figsize=(12,4))

ax1 = plt.subplot(1,2,1)
plt.plot(delta,ZT22_1, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24_1, 'b--', label="$m=2,n=4$")
plt.plot(delta,ZT26_1, 'k--', label="$m=2,n=6$")
#plt.plot(delta,ZT44_1, 'r--', label="$m=4,n=4$")
plt.plot(delta,ZT66_1, 'g-', label="$m=6,n=6$")
plt.plot(delta,ZT46_1, 'r:', label="$m=4,n=6$")
plt.axis([0,10,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\Delta/k_B T$')
plt.ylabel('$ZT_{max}$')
plt.title('$\kappa_{ph} = \kappa_0/3$',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax2 = plt.subplot(1,2,2)
plt.plot(delta,ZT22p_1, 'b-', label="$m=2,n=2$")
#plt.plot(delta,ZT24p, 'b--', label="$m=2,n=4$")
plt.plot(delta,ZT26p_1, 'k--', label="$m=2,n=6$")
#plt.plot(delta,ZT44p_1, 'r--', label="$m=4,n=4$")
plt.plot(delta,ZT66p_1, 'g-', label="$m=6,n=6$")
plt.plot(delta,ZT46p_1, 'r:', label="$m=4,n=6$")
plt.axis([0,10,0,4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.title('$\kappa_{ph} = (10/3)\kappa_0$',fontsize=14)
plt.xlabel('$\Delta/k_B T$')
#plt.ylabel('$ZT_{max}$')
plt.legend(bbox_to_anchor=(1.6,1))
# Hide the right and top spines (axis)
ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()
plt.savefig('FigZTvsDelta_new_comb_1D.pdf')

# %%
#Plotting the band and density of states

#----DOS plotting----

def DOS(E,d,n):
    ds = zeros(E.size)
    for i in range(E.size):
        if(E[i]>0.15):
            ds[i] = (1/n)*(1/pi*d**0.5)**d*(E[i]-0.15)**(-1+d/n)
        elif(-0.15<E[i]<0.15):
            ds[i]=0
        else:
            ds[i] = (1/n)*(1/pi*d**0.5)**d*(-E[i]-0.15)**(-1+d/n)
    return ds

eta = linspace(-6,6,1000)

#---Dispersion,DOS 1D---
plt.figure(figsize=(8,4))

ax1 = plt.subplot(1,2,1)
plt.plot(eta, (eta/pi)**2 + 0.15, 'b-', label="$n=2$")
plt.plot(eta, -(eta/pi)**2 - 0.15, 'b-', label="$n=2$")
plt.plot(eta, (eta/pi)**4 + 0.15, 'g-', label="$n=4$")
plt.plot(eta, -(eta/pi)**4 - 0.15, 'g-', label="$n=4$")
plt.plot(eta, (eta/pi)**6 + 0.15, 'r-', label="$n=6$")
plt.plot(eta, -(eta/pi)**6 - 0.15, 'r-', label="$n=6$")
plt.axis([-pi,pi,-1,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$k$')
plt.ylabel('$E$')
#plt.legend()

ax2 = plt.subplot(1,2,2)
plt.plot(DOS(eta,1,2)/pi, eta, 'b-', label="$n=2$")
plt.plot(DOS(eta,1,4)/pi, eta, 'g-', label="$n=4$")
plt.plot(DOS(eta,1,6)/pi, eta, 'r-', label="$n=6$")
plt.axis([0,0.5,-1,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$DOS$')
#plt.ylabel('$E$')
plt.tight_layout()
plt.legend()
plt.savefig('figTE_DOS1D.pdf')

#---Dispersion,DOS 2D---
plt.figure(figsize=(8,4))

ax1 = plt.subplot(1,2,1)
plt.plot(eta, (eta/(1.41*pi))**2 + 0.15, 'b-', label="$n=2$")
plt.plot(eta, -(eta/(1.41*pi))**2 - 0.15, 'b-', label="$n=2$")
plt.plot(eta, (eta/(1.41*pi))**4 + 0.15, 'g-', label="$n=4$")
plt.plot(eta, -(eta/(1.41*pi))**4 - 0.15, 'g-', label="$n=4$")
plt.plot(eta, (eta/(1.41*pi))**6 + 0.15, 'r-', label="$n=6$")
plt.plot(eta, -(eta/(1.41*pi))**6 - 0.15, 'r-', label="$n=6$")
plt.axis([-4.44,4.44,-1,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$k$')
plt.ylabel('$E$')
#plt.legend()

ax2 = plt.subplot(1,2,2)
plt.plot(DOS(eta,2,2)/(2*pi), eta, 'b-', label="$n=2$")
plt.plot(DOS(eta,2,4)/(2*pi), eta, 'g-', label="$n=4$")
plt.plot(DOS(eta,2,6)/(2*pi), eta, 'r-', label="$n=6$")
plt.axis([0,0.1,-1,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$DOS$')
#plt.ylabel('$E$')
plt.tight_layout()
plt.legend()
plt.savefig('figTE_DOS2D.pdf')

#---Dispersion,DOS 3D---
plt.figure(figsize=(8,4))

ax1 = plt.subplot(1,2,1)
plt.plot(eta, (eta/(1.73*pi))**2 + 0.15, 'b-', label="$n=2$")
plt.plot(eta, -(eta/(1.73*pi))**2 - 0.15, 'b-', label="$n=2$")
plt.plot(eta, (eta/(1.73*pi))**4 + 0.15, 'g-', label="$n=4$")
plt.plot(eta, -(eta/(1.73*pi))**4 - 0.15, 'g-', label="$n=4$")
plt.plot(eta, (eta/(1.73*pi))**6 + 0.15, 'r-', label="$n=6$")
plt.plot(eta, -(eta/(1.73*pi))**6 - 0.15, 'r-', label="$n=6$")
plt.axis([-5.44,5.44,-1,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$k$')
plt.ylabel('$E$')
#plt.legend()

ax2 = plt.subplot(1,2,2)
plt.plot(DOS(eta,3,2)/(2*pi*pi), eta, 'b-', label="$n=2$")
plt.plot(DOS(eta,3,4)/(2*pi*pi), eta, 'g-', label="$n=4$")
plt.plot(DOS(eta,3,6)/(2*pi*pi), eta, 'r-', label="$n=6$")
plt.axis([0,0.05,-1,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$DOS$')
#plt.ylabel('$E$')
plt.tight_layout()
plt.legend()
plt.savefig('figTE_DOS3D.pdf')

# %%
infty = 100
kT_A  = 0.03   #Boltzmann constant times temperature
a = 5.44        #Normalization factor A
C2 = 1/(4*pi)
C3 = 1/(6*pi*pi)
kph = a*(kT_A)


# Define kernel:
def L0c(xx,N,D):
    def integrand (x,xx):
        return (x+xx-D)**((1+N)/N) * (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, D-xx, infty, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L1c(xx,N,D):
    def integrand (x,xx):
        return (x+xx-D)**((1+N)/N)*x* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, D-xx, infty, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L2c(xx,N,D):
    def integrand (x,xx):
        return (x+xx-D)**((1+N)/N) * (x**2)* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, D-xx, infty, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L0v(xx,N,D):
    def integrand (x,xx):
        return (-x-xx-D)**((1+N)/N) * (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, -infty, -D-xx, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L1v(xx,N,D):
    def integrand (x,xx):
        return (-x-xx-D)**((1+N)/N)*x* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, -infty, -D-xx, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def L2v(xx,N,D):
    def integrand (x,xx):
        return (-x-xx-D)**((1+N)/N) * (x**2)* (exp(x) / (exp(x)+1)**2)
    I, error = quad(integrand, -infty, -D-xx, args=(xx))
    return N*C3*(a*(kT_A)**(1/N))*I

def S_c(x,n,W):
    sc = zeros(x.size)
    for i in range(x.size):
        sc[i] = -L1c(x[i],n,W)/L0c(x[i],n,W)
    return sc

def sigma_c(x,n,W):
    sgm = zeros(x.size)
    for i in range(x.size):
        sgm[i] = L0c(x[i],n,W)
    return sgm

def kappa_c(x,n,W):
    kpp = zeros(x.size)
    for i in range(x.size):
        kpp[i] = (L2c(x[i],n,W)-(L1c(x[i],n,W)**2/L0c(x[i],n,W)))
    return kpp

def S_v(x,n,W):
    sc = zeros(x.size)
    for i in range(x.size):
        sc[i] = -L1v(x[i],n,W)/L0v(x[i],n,W)
    return sc

def sigma_v(x,n,W):
    sgm = zeros(x.size)
    for i in range(x.size):
        sgm[i] = L0v(x[i],n,W)
    return sgm

def kappa_v(x,n,W):
    kpp = zeros(x.size)
    for i in range(x.size):
        kpp[i] = (L2v(x[i],n,W)-(L1v(x[i],n,W)**2/L0v(x[i],n,W)))
    return kpp

def sigma(x,m,n,W):
    return sigma_c(x,m,W)+sigma_v(x,n,W)

def S(x,m,n,W):
    return (sigma_c(x,m,W)*S_c(x,m,W)+sigma_v(x,n,W)*S_v(x,n,W))/sigma(x,m,n,W)

def kappa(x,m,n,W):
    return kappa_c(x,m,W)+kappa_v(x,n,W)+(sigma_c(x,m,W)*sigma_v(x,n,W)*(S_c(x,m,W)-S_v(x,n,W))**2)/sigma(x,m,n,W)


def PF(Sc,Sgm):
    return (Sc**2)*Sgm

def ZT(x,m,n,W,alpha):
    return (S(x,m,n,W)**2 * sigma(x,m,n,W))/(kappa(x,m,n,W) + alpha)

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(10,3))

ax1 = plt.subplot(1,3,1)
plt.plot(eta, sigma_c(eta,4,3), 'b--', label="$\sigma_c$")
plt.plot(eta, sigma_v(eta,4,3), 'r--', label="$\sigma_v$")
plt.plot(eta, sigma(eta,4,4,3), 'g-', label="$\sigma$")
plt.axis([-8,8,0,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma$')
#plt.title('(a)')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(1,3,2)
plt.plot(eta, kappa_c(eta,4,3), 'b--', label="$\kappa_{e,c}$")
plt.plot(eta, kappa_v(eta,4,3), 'r--', label="$\kappa_{e,v}$")
plt.plot(eta, kappa(eta,4,4,3), 'g-', label="$\kappa_e$")
plt.axis([-8,8,0,3]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('n=4',fontsize=14)
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e$')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(1,3,3)
plt.plot(eta, S_c(eta,4,3), 'b--', label="$S_c$")
plt.plot(eta, S_v(eta,4,3), 'r--', label="$S_v$")
plt.plot(eta, S(eta,4,4,3), 'g-', label="$S$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S$')
plt.legend(loc='upper right')
plt.tight_layout()

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 
# ----sigma----
plt.figure(figsize=(10,3))

ax1 = plt.subplot(1,3,1)
plt.plot(eta, sigma_c(eta,4,3), 'b--', label="$\sigma_c$")
plt.plot(eta, sigma_v(eta,4,3), 'r--', label="$\sigma_v$")
plt.plot(eta, sigma(eta,4,4,3), 'g-', label="$\sigma$")
plt.axis([-8,8,0,1]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\sigma$')
#plt.title('(a)')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEsigma2462D.pdf')

# ----kappa----igsize=(6,3.5))
ax2 = plt.subplot(1,3,2)
plt.plot(eta, kappa_c(eta,4,3), 'b--', label="$\kappa_{e,c}$")
plt.plot(eta, kappa_v(eta,4,3), 'r--', label="$\kappa_{e,v}$")
plt.plot(eta, kappa(eta,4,4,3), 'g-', label="$\kappa_e$")
plt.axis([-8,8,0,3]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.legend(bbox_to_anchor=(1.1,1))
plt.title('n=4',fontsize=14)
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$\kappa_e$')
plt.legend()
plt.tight_layout()
#plt.savefig('figTEkappa2462D.pdf')

ax3 = plt.subplot(1,3,3)
plt.plot(eta, S_c(eta,4,3), 'b--', label="$S_c$")
plt.plot(eta, S_v(eta,4,3), 'r--', label="$S_v$")
plt.plot(eta, S(eta,4,4,3), 'g-', label="$S$")
plt.axis([-8,8,-5,5]) # the format is [xmin,xmax,ymin,ymax]
# in plt.xlabel or ylabel, the option r is not necessary
#plt.title('(c)')
plt.xlabel('$\mu/k_B T$')
plt.ylabel('$S$')
plt.legend(loc='upper right')
plt.tight_layout()

# %%
kappae1 = kappa(eta,4,4,3)
sigma1 = sigma(eta,4,4,3)

# %%
kappae2 = kappa(eta,4,4,3)
sigma2 = sigma(eta,4,4,3)

# %%
plt.plot(eta,kappae1)
plt.plot(eta,kappae2)

# %%
plt.plot(eta,sigma1)
plt.plot(eta,sigma2)

# %%
plt.plot(eta,S(eta,4,4,3))
plt.plot(eta,S(eta,4,4,5))
plt.plot(eta,S(eta,4,4,7))
plt.plot(eta,S(eta,4,4,9))
plt.plot(eta,S(eta,4,4,11))

# %%
npoint = 201
eta = linspace(-10, 10, npoint) 

plt.plot(eta,S(eta,4,4,1)**2*sigma(eta,4,4,1))
plt.plot(eta,S(eta,4,4,2)**2*sigma(eta,4,4,2))
plt.plot(eta,S(eta,4,4,3)**2*sigma(eta,4,4,3))
plt.plot(eta,S(eta,4,4,4)**2*sigma(eta,4,4,4))
plt.plot(eta,S(eta,4,4,5)**2*sigma(eta,4,4,5))

# %%
plt.figure(figsize=(11,12))

ax1 = plt.subplot(3,2,1)

plt.plot(2*delta,ZT22, 'b-', label="$m=2,n=2$")
plt.plot(2*delta,ZT44, 'r-', label="$m=2,n=4$")
plt.plot(2*delta,ZT66, 'g-', label="$m=2,n=6$")
plt.plot(2*delta,ZT24, 'r:', label="$m=4,n=4$")
plt.plot(2*delta,ZT26, 'b--', label="$m=4,n=6$")
plt.plot(2*delta,ZT46, 'g:', label="$m=6,n=6$")
plt.axis([0,20,0,2.2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.text(14.4,2,'$\kappa_{ph} = \kappa_0/3$',fontsize=14)
plt.text(0.2,2,'3D',fontsize=14)
plt.xlabel('$E_g/k_B T$')
plt.ylabel('$ZT_{max}$')
plt.title('(a)',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax2 = plt.subplot(3,2,2)

plt.plot(2*delta,ZT22p, 'b-', label="$m=2,n=2$")
plt.plot(2*delta,ZT44p, 'r-', label="$m=2,n=4$")
plt.plot(2*delta,ZT66p, 'g-', label="$m=6,n=6$")
plt.plot(2*delta,ZT24p, 'r:', label="$m=2,n=4$")
plt.plot(2*delta,ZT26p, 'b--', label="$m=2,n=6$")
plt.plot(2*delta,ZT46p, 'g:', label="$m=4,n=6$")
plt.axis([0,20,0,2.2]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.text(13,2,'$\kappa_{ph} = 10\kappa_0/3$',fontsize=14)
plt.xlabel('$E_g/k_B T$')
#plt.ylabel('$ZT_{max}$')
plt.title('(b)',fontsize=14)
plt.legend(bbox_to_anchor=(1.6,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax3 = plt.subplot(3,2,3)

plt.plot(2*delta,ZT22_2, 'b-', label="$m=2,n=2$")
plt.plot(2*delta,ZT44_2, 'r-', label="$m=2,n=4$")
plt.plot(2*delta,ZT66_2, 'g-', label="$m=2,n=6$")
plt.plot(2*delta,ZT24_2, 'r:', label="$m=4,n=4$")
plt.plot(2*delta,ZT26_2, 'b--', label="$m=4,n=6$")
plt.plot(2*delta,ZT46_2, 'g:', label="$m=6,n=6$")
plt.axis([0,20,0,2.7]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.text(14.4,2.5,'$\kappa_{ph} = \kappa_0/3$',fontsize=14)
plt.text(0.2,2.5,'2D',fontsize=14)
plt.xlabel('$E_g/k_B T$')
plt.ylabel('$ZT_{max}$')
plt.title('(c)',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax4 = plt.subplot(3,2,4)

plt.plot(2*delta,ZT22p_2, 'b-', label="$m=2,n=2$")
plt.plot(2*delta,ZT44p_2, 'r-', label="$m=2,n=4$")
plt.plot(2*delta,ZT66p_2, 'g-', label="$m=2,n=6$")
plt.plot(2*delta,ZT24p_2, 'r:', label="$m=4,n=4$")
plt.plot(2*delta,ZT26p_2, 'b--', label="$m=4,n=6$")
plt.plot(2*delta,ZT46p_2, 'g:', label="$m=6,n=6$")
plt.axis([0,20,0,2.7]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.text(13,2.5,'$\kappa_{ph} = 10\kappa_0/3$',fontsize=14)
plt.xlabel('$E_g/k_B T$')
#plt.ylabel('$ZT_{max}$')
plt.title('(d)',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax5 = plt.subplot(3,2,5)

plt.plot(2*delta,ZT22_1, 'b-', label="$m=2,n=2$")
plt.plot(2*delta,ZT44_1, 'r-', label="$m=2,n=4$")
plt.plot(2*delta,ZT66_1, 'g-', label="$m=2,n=6$")
plt.plot(2*delta,ZT24_1, 'r:', label="$m=4,n=4$")
plt.plot(2*delta,ZT26_1, 'b--', label="$m=4,n=6$")
plt.plot(2*delta,ZT46_1, 'g:', label="$m=6,n=6$")
plt.axis([0,20,0,4.4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.text(14.4,4.1,'$\kappa_{ph} = \kappa_0/3$',fontsize=14)
plt.text(0.2,4.1,'1D',fontsize=14)
plt.xlabel('$E_g/k_B T$')
plt.ylabel('$ZT_{max}$')
plt.title('(e)',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

ax2 = plt.subplot(3,2,6)

plt.plot(2*delta,ZT22p_1, 'b-', label="$m=2,n=2$")
plt.plot(2*delta,ZT44p_1, 'r-', label="$m=2,n=4$")
plt.plot(2*delta,ZT66p_1, 'g-', label="$m=2,n=6$")
plt.plot(2*delta,ZT24p_1, 'r:', label="$m=4,n=4$")
plt.plot(2*delta,ZT26p_1, 'b--', label="$m=4,n=6$")
plt.plot(2*delta,ZT46p_1, 'g:', label="$m=6,n=6$")
plt.axis([0,20,0,4.4]) # the format is [xmin,xmax,ymin,ymax]
# in plt.text, the option r before the LaTeX is necessary 
#plt.text(10,3, r'$n = 2$', color='b')
#plt.text(10,4.2, r'$n = 4$', color='r')
#plt.text(10,5, r'$n = 6$', color='g')
# in plt.xlabel or ylabel, the option r is not necessary
plt.text(13,4.1,'$\kappa_{ph} = 10\kappa_0/3$',fontsize=14)
plt.xlabel('$E_g/k_B T$')
#plt.ylabel('$ZT_{max}$')
plt.title('(f)',fontsize=14)
#plt.legend(bbox_to_anchor=(1.1,1.1))
# Hide the right and top spines (axis)
ax = plt.gca()
#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)
# Remove whitespaces around the figure
plt.tight_layout()

plt.savefig('figTEZTvsDeltaAll.pdf')

# %%
plt.plot(delta,eta26/10)

# %%
abs(-3)
# Out:
# 3

# %%
plt.plot(delta,abs(eta26 - 100)/5)
plt.plot(delta,delta)
#plt.xlim([-5,5])

# %%
# Out:
# -2.8

# %%
# Out:
# array([-1.999e+01, -1.979e+01, -1.959e+01, -1.939e+01, -1.919e+01,
#        -1.899e+01, -1.879e+01, -1.859e+01, -1.839e+01, -1.819e+01,
#        -1.799e+01, -1.779e+01, -1.759e+01, -1.739e+01, -1.719e+01,
#        -1.699e+01, -1.679e+01, -1.659e+01, -1.639e+01, -1.619e+01,
#        -1.599e+01, -1.579e+01, -1.559e+01, -1.539e+01, -1.519e+01,
#        -1.499e+01, -1.479e+01, -1.459e+01, -1.439e+01, -1.419e+01,
#        -1.399e+01, -1.379e+01, -1.359e+01, -1.339e+01, -1.319e+01,
#        -1.299e+01, -1.279e+01, -1.259e+01, -1.239e+01, -1.219e+01,
#        -1.199e+01, -1.179e+01, -1.159e+01, -1.139e+01, -1.119e+01,
#        -1.099e+01, -1.079e+01, -1.059e+01, -1.039e+01, -1.019e+01,
#        -9.990e+00, -9.790e+00, -9.590e+00, -9.390e+00, -9.190e+00,
#        -8.990e+00, -8.790e+00, -8.590e+00, -8.390e+00, -8.190e+00,
#        -7.990e+00, -7.790e+00, -7.590e+00, -7.390e+00, -7.190e+00,
#        -6.990e+00, -6.790e+00, -6.590e+00, -6.390e+00, -6.190e+00,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-bc54b4b75c0e> in <module>
# ----> 1 eta[999]
#
# IndexError: index 999 is out of bounds for axis 0 with size 201
